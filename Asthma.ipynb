# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_excel("CaliEnviro SFV.xlsx")
df
# Out:
#      FID  Shape *       tract  pop2010   California    ZIP          City  \
# 0      0  Polygon  6111008304     5484      Ventura  93063   Simi Valley
# 1      1  Polygon  6111007511     2222      Ventura  91307    West Hills
# 2      2  Polygon  6037139504     3476  Los Angeles  91316        Encino
# 3      3  Polygon  6037139503     4657  Los Angeles  91316        Encino
# 4      4  Polygon  6037139401     2645  Los Angeles  91356       Tarzana
# ..   ...      ...         ...      ...          ...    ...           ...
# 374  374  Polygon  6037143700     3748  Los Angeles  90068   Los Angeles
# 375  375  Polygon  6037141600     4029  Los Angeles  91403  Sherman Oaks
# 376  376  Polygon  6037143800     4878  Los Angeles  91604   Studio City
# 377  377  Polygon  6037143902     3000  Los Angeles  91423  Sherman Oaks
# 378  378  Polygon  6037143901     4068  Los Angeles  91604   Studio City
#
#       Longitude   Latitude  CIscore  ...  African_Am  Native_Ame  Asian_Amer  \
# ...

# %%
## Full Data Heat Map

corr=df.corr()
corr
f,ax=plt.subplots(figsize=(20,20))
sns.heatmap(corr,annot=True,linewidths=.5,fmt='.1f',ax=ax)
plt.show()

# %%
new_df = df.drop(columns=['FID','Shape *','Longitude','Latitude','OBJECTID_1'])
new_df
new_df = new_df.drop(columns=['CIscore','ozone','pm','diesel','drink','pest','RSEIhaz','traffic','cleanups','gwthreats','haz','iwb','swis','Pollution','asthma',
                     'lbw','cvd','edu','ling','pov','unemp','housingB','PopChar'])
new_df
# Out:
#           tract  pop2010   California    ZIP          City  CIscoreP  ozoneP  \
# 0    6111008304     5484      Ventura  93063   Simi Valley        24      78
# 1    6111007511     2222      Ventura  91307    West Hills        25      78
# 2    6037139504     3476  Los Angeles  91316        Encino        71      82
# 3    6037139503     4657  Los Angeles  91316        Encino        54      82
# 4    6037139401     2645  Los Angeles  91356       Tarzana        70      82
# ..          ...      ...          ...    ...           ...       ...     ...
# 374  6037143700     3748  Los Angeles  90068   Los Angeles        32      69
# 375  6037141600     4029  Los Angeles  91403  Sherman Oaks        25      74
# 376  6037143800     4878  Los Angeles  91604   Studio City        48      69
# 377  6037143902     3000  Los Angeles  91423  Sherman Oaks        11      69
# 378  6037143901     4068  Los Angeles  91604   Studio City         8      69
#
# ...

# %%
## Partial Data Heat Map

corr=new_df.corr()
corr
f,ax=plt.subplots(figsize=(20,20))
sns.heatmap(corr,annot=True,linewidths=.5,fmt='.1f',ax=ax)
plt.show()

# %%
sns.pairplot(new_df,x_vars=['tract', 'pop2010', 'California', 'ZIP', 'City', 'CIscoreP', 'ozoneP',
       'pmP', 'dieselP', 'drinkP', 'pestP', 'RSEIhazP', 'trafficP'],y_vars='asthmaP');

# %%
sns.pairplot(new_df,x_vars=['cleanupsP', 'gwthreatsP', 'hazP', 'iwbP', 'swisP', 'PollutionS',
       'PollutionP', 'asthmaP', 'lbwP', 'cvdP', 'eduP', 'lingP', 'povP',
       'unempP', 'housingBP', 'PopCharSco', 'PopCharP', 'Children_u'],y_vars='asthmaP');

# %%
sns.pairplot(new_df,x_vars=['Pop_11_64_', 'Elderly_ov', 'Hispanic_p', 'White_pct', 'African_Am',
       'Native_Ame', 'Asian_Amer', 'Other_pct'],y_vars='asthmaP');

# %%
sns.pairplot(new_df,x_vars=['CIdecile', 'CIvigintil',
       'Shape_Leng', 'Shape_Area', 'CES2018_Rn'],y_vars='asthmaP');
plt.set_size_inches(15,5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-a89854568060> in <module>
#       1 sns.pairplot(new_df,x_vars=['CIdecile', 'CIvigintil',
#       2        'Shape_Leng', 'Shape_Area', 'CES2018_Rn'],y_vars='asthmaP');
# ----> 3 plt.set_size_inches(15,5)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_size_inches'

# %%
new_df.columns

# %% [markdown]
# ## Main Correlations

# %%
sns.pairplot(new_df,x_vars=['California', 'ZIP', 'City', 'CIscoreP','ozoneP','dieselP','drinkP','RSEIhazP'],y_vars='asthmaP');

# %%
sns.pairplot(new_df,x_vars=['trafficP','cleanupsP','PollutionS','PollutionP','cvdP','eduP','lingP'],y_vars='asthmaP');

# %%
sns.pairplot(new_df,x_vars=['povP','housingBP', 'PopCharSco', 'PopCharP', 'Children_u','Pop_11_64_'],y_vars='asthmaP');

# %%
sns.pairplot(new_df,x_vars=['Elderly_ov', 'Hispanic_p', 'White_pct', 'African_Am',
       'Native_Ame', 'Asian_Amer', 'Other_pct'],y_vars='asthmaP');

# %%
sns.pairplot(new_df,x_vars=['CIdecile', 'CIvigintil',
       'Shape_Leng', 'Shape_Area', 'CES2018_Rn'],y_vars='asthmaP');
