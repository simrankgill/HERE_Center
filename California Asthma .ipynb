# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df= pd.read_excel("CES 3.0.xlsx")
df
# Out:
#       Census Tract  Total Population California County    ZIP  \
# 0       6019001100              3174           Fresno   93706
# 1       6071001600              6133    San Bernardino  91761
# 2       6019000200              3167           Fresno   93706
# 3       6077000801              6692       San Joaquin  95203
# 4       6019001500              2206           Fresno   93725
# ...            ...               ...               ...    ...
# 8030    6009000504               942        Calaveras   95223
# 8031    6065940100               166        Riverside   92239
# 8032    6053011502              1710         Monterey   93923
# 8033    6083980100                11     Santa Barbara     57
# 8034    6111980000                56          Ventura      61
#
#      Nearby City \n(to help approximate location only)   Longitude   Latitude  \
# 0                                               Fresno -119.781696  36.709695
# ...

# %%
# Dropping columns with many null values 
df = df.drop(columns = ['CES 3.0 Score', ' CES 3.0 Percentile','CES 3.0 \nPercentile Range'])

# %%
#Dropping rows with null values 
df = df.dropna()
df
# Out:
#       Census Tract  Total Population California County    ZIP  \
# 0       6019001100              3174           Fresno   93706
# 1       6071001600              6133    San Bernardino  91761
# 2       6019000200              3167           Fresno   93706
# 3       6077000801              6692       San Joaquin  95203
# 4       6019001500              2206           Fresno   93725
# ...            ...               ...               ...    ...
# 7922    6037262802              3759       Los Angeles  90272
# 7924    6053011602              5266         Monterey   93923
# 7926    6073008102              3395         San Diego  92037
# 7927    6013352102              5586      Contra Costa  94556
# 7928    6013392000              2451      Contra Costa  94708
#
#      Nearby City \n(to help approximate location only)   Longitude   Latitude  \
# 0                                               Fresno -119.781696  36.709695
# ...

# %%
## Full Data Heat Map

corr=df.corr()
corr
f,ax=plt.subplots(figsize=(20,20))
sns.heatmap(corr,annot=True,linewidths=.5,fmt='.1f',ax=ax)
plt.show()

# %% [markdown]
# ## Ozone Correlations

# %%
## Ozone and Longitude with correlation value of .6
sns.jointplot(x=df["Ozone"], y=df["Longitude"], kind='scatter', s=200, color='m', edgecolor="skyblue", linewidth=2);

# %%
## Ozone and Dring Water with correlation value of .6
sns.jointplot(x=df["Ozone"], y=df["Drinking Water"], kind='kde', color="skyblue")

# %%
## Ozone and Cardiovascular Disease with correlation value of .4
sns.jointplot(x=df["Ozone"], y=df["Cardiovascular Disease"], kind='kde', color="skyblue");

# %% [markdown]
# ## PM2.5

# %%
## PM2.5 and Pollution Burden Score Correlation of .6 
#  PM2.5 definition - refers to particles that have diameter less than 2.5 micrometres
#                    (more than 100 times thinner than a human hair) and remain suspended for longer. 
#                    These particles are formed as a result of burning fuel and chemical reactions that 
#                    take place in the atmosphere
sns.jointplot(x=df["PM2.5"], y=df["Pollution Burden Score"], kind='kde', color="skyblue");

# %% [markdown]
# ## Pollution Burden

# %%
## PM2.5 and Pollution Burden Score Correlation of .6 
#  PM2.5 definition - refers to particles that have diameter less than 2.5 micrometres
#                    (more than 100 times thinner than a human hair) and remain suspended for longer. 
#                    These particles are formed as a result of burning fuel and chemical reactions that 
#                    take place in the atmosphere
sns.jointplot(x=df["PM2.5"], y=df["Pollution Burden Score"], kind='kde', color="skyblue");

# %%
##Diesel PM Pctl and Pollution Burden Score -> .5
sns.jointplot(x=df["Diesel PM Pctl"], y=df["Pollution Burden Score"], kind='hex');

# %%
## Drinking Water and Pollution Burden Score  -> .5 
sns.jointplot(x=df["Drinking Water"], y=df["Pollution Burden Score"],  kind='kde', color="skyblue");

# %%
## Traffic Pctl and Pollution Burden Score  -> .6
sns.jointplot(x=df["Traffic Pctl"], y=df["Pollution Burden Score"],  kind='hex', color="skyblue");

# %% [markdown]
# ## Asthma Correlation

# %%
## Asthma and Cardiovascular Disease ->.7

sns.jointplot(x=df["Asthma"], y=df["Cardiovascular Disease"],kind='scatter', s=50, color='m', edgecolor="skyblue", linewidth=2);

# %%
## Asthma and Education ->.4

sns.jointplot(x=df["Asthma"], y=df["Education"],kind='scatter', s=50, color='m', edgecolor="skyblue", linewidth=2);

# %%
## Asthma and Poverty ->.4

sns.jointplot(x=df["Asthma"], y=df["Poverty"],kind='scatter', s=50, color='m', edgecolor="skyblue", linewidth=2);

# %%
## Asthma and Unemployment ->.4

sns.jointplot(x=df["Asthma"], y=df["Unemployment"],kind='scatter', s=50, color='m', edgecolor="skyblue", linewidth=2);

# %% [markdown]
# ## Education

# %%
## Education and Unemployment ->.5

sns.jointplot(x=df["Education"], y=df["Unemployment"],kind='scatter', s=50, color='m', edgecolor="skyblue", linewidth=2);

# %%
## Education and Linguistic Isolation ->.7

sns.jointplot(x=df["Education"], y=df["Linguistic Isolation"],kind='scatter', s=50, color='m', edgecolor="skyblue", linewidth=2);

# %%
## Education and Housing Burden ->.6

sns.jointplot(x=df["Education"], y=df["Housing Burden"],kind='scatter', s=50, color='m', edgecolor="skyblue", linewidth=2);

# %%
## Education and Poverty -> .8
sns.jointplot(x=df["Education"], y=df["Poverty"],kind='scatter', s=50, color='m', edgecolor="skyblue", linewidth=2);

# %%
df.columns
# Out:
# Index(['Census Tract', 'Total Population', 'California County', 'ZIP',
#        'Nearby City \n(to help approximate location only)', 'Longitude',
#        'Latitude', 'SB 535 Disadvantaged Community', 'Ozone', 'Ozone Pctl',
#        'PM2.5', 'PM2.5 Pctl', 'Diesel PM', 'Diesel PM Pctl', 'Drinking Water',
#        'Drinking Water Pctl', 'Pesticides', 'Pesticides Pctl', 'Tox. Release',
#        'Tox. Release Pctl', 'Traffic', 'Traffic Pctl', 'Cleanup Sites',
#        'Cleanup Sites Pctl', 'Groundwater Threats', 'Groundwater Threats Pctl',
#        'Haz. Waste', 'Haz. Waste Pctl', 'Imp. Water Bodies',
#        'Imp. Water Bodies Pctl', 'Solid Waste', 'Solid Waste Pctl',
#        'Pollution Burden', 'Pollution Burden Score', 'Pollution Burden Pctl',
#        'Asthma', 'Asthma Pctl', 'Low Birth Weight', 'Low Birth Weight Pctl',
#        'Cardiovascular Disease', 'Cardiovascular Disease Pctl', 'Education',
#        'Education Pctl', 'Linguistic Isolation', 'Linguistic Isolation Pctl',
# ...

# %%
countydf = df.groupby(['California County']).mean()
countydf
# Out:
#                    Census Tract  Total Population           ZIP   Longitude  \
# California County
# Alameda            6.001427e+09       4244.863372  94586.497093 -122.118401
# Amador             6.005000e+09       4336.142857  95652.428571 -120.760981
# Butte              6.007002e+09       4358.978723  95952.106383 -121.704450
# Calaveras          6.009000e+09       4959.555556  95238.888889 -120.568149
# Colusa             6.011000e+09       4283.800000  95948.400000 -122.140250
# Contra Costa       6.013342e+09       5153.661538  94586.948718 -122.053224
# Del Norte          6.015000e+09       5453.000000  95531.000000 -124.250970
# El Dorado          6.017031e+09       4582.394737  93261.500000 -120.709850
# Fresno             6.019004e+09       4748.327869  93672.568306 -119.768287
# Glenn              6.021010e+09       4687.000000  95959.833333 -122.195618
# Humboldt           6.023006e+09       4655.333333  95522.518519 -124.065833
# ...

# %%
## Full Data Heat Map

corr=countydf.corr()
corr
f,ax=plt.subplots(figsize=(20,20))
sns.heatmap(corr,annot=True,linewidths=.5,fmt='.1f',ax=ax)
plt.show()

# %%
countydf.columns
# Out:
# Index(['Census Tract', 'Total Population', 'ZIP', 'Longitude', 'Latitude',
#        'Ozone', 'Ozone Pctl', 'PM2.5', 'PM2.5 Pctl', 'Diesel PM',
#        'Diesel PM Pctl', 'Drinking Water', 'Drinking Water Pctl', 'Pesticides',
#        'Pesticides Pctl', 'Tox. Release', 'Tox. Release Pctl', 'Traffic',
#        'Traffic Pctl', 'Cleanup Sites', 'Cleanup Sites Pctl',
#        'Groundwater Threats', 'Groundwater Threats Pctl', 'Haz. Waste',
#        'Haz. Waste Pctl', 'Imp. Water Bodies', 'Imp. Water Bodies Pctl',
#        'Solid Waste', 'Solid Waste Pctl', 'Pollution Burden',
#        'Pollution Burden Score', 'Pollution Burden Pctl', 'Asthma',
#        'Asthma Pctl', 'Low Birth Weight', 'Low Birth Weight Pctl',
#        'Cardiovascular Disease', 'Cardiovascular Disease Pctl', 'Education',
#        'Education Pctl', 'Linguistic Isolation', 'Linguistic Isolation Pctl',
#        'Poverty', 'Poverty Pctl', 'Unemployment', 'Unemployment Pctl',
# ...

# %%
county = np.array(countydf.index)
Ozone  = np.array(countydf['Ozone'])

# %%
## Note: Ozone -- Amount of daily maxumum 8 hour Ozone concentration
# Long-term exposure to ozone is linked to aggravation of asthma, and 
# is likely to be one of many causes of asthma development. Long-term
# exposures to higher concentrations of ozone may also be linked to 
# permanent lung damage, such as abnormal lung development in children.

plt.figure(figsize=(20,5))
plt.plot( county, Ozone , marker='o', color='mediumvioletred')
plt.title("Counties by Ozone", fontsize = 17)
plt.ylabel("Ozone",fontsize = 14)
plt.xlabel("Counties",fontsize =14)
plt.xticks(rotation=90)
plt.show()

# %%
## Tox. Release -- tox disposal facility
ToxRelease = np.array(countydf['Tox. Release'])

plt.figure(figsize=(20,5))
plt.plot( county, ToxRelease , marker='o', color='mediumvioletred')
plt.title("Counties by Tox. Release", fontsize = 17)
plt.ylabel("Tox. Release",fontsize = 14)
plt.xlabel("Counties",fontsize =14)
plt.xticks(rotation=90)
plt.show()

# %%
## Drinking Water
DrinkingWater = np.array(countydf['Drinking Water'])

plt.figure(figsize=(20,5))
plt.plot( county, DrinkingWater , marker='o', color='mediumvioletred')
plt.title("Counties by Drinking Water", fontsize = 17)
plt.ylabel("Drinking Water",fontsize = 14)
plt.xlabel("Counties",fontsize =14)
plt.xticks(rotation=90)
plt.show()

# %%
## Pollution Burden

PollutionBurden = np.array(countydf['Pollution Burden'])

plt.figure(figsize=(20,5))
plt.plot( county, PollutionBurden , marker='o', color='mediumvioletred')
plt.title("Counties by Pollution Burden", fontsize = 17)
plt.ylabel("Pollution Burden",fontsize = 14)
plt.xlabel("Counties",fontsize =14)
plt.xticks(rotation=90);

# %%
## Asthma

Asthma = np.array(countydf['Asthma'])

plt.figure(figsize=(20,5))
plt.plot( county, Asthma , marker='o', color='mediumvioletred')
plt.title("Counties by Asthma", fontsize = 17)
plt.ylabel("Asthma",fontsize = 14)
plt.xlabel("Counties",fontsize =14)
plt.xticks(rotation=90);

# %%
## Low Birth Weight

LowBirthWeight = np.array(countydf['Low Birth Weight'])

plt.figure(figsize=(20,5))
plt.plot( county, LowBirthWeight , marker='o', color='mediumvioletred')
plt.title("Counties by Low Birth Weight", fontsize = 17)
plt.ylabel("Low Birth Weight",fontsize = 14)
plt.xlabel("Counties",fontsize =14)
plt.xticks(rotation=90);

# %%
## Education  --- Percent of population over 25 with less than a high school education

Education = np.array(countydf['Education'])

plt.figure(figsize=(20,5))
plt.plot( county, Education , marker='o', color='mediumvioletred')
plt.title("Counties by Education", fontsize = 17)
plt.ylabel("Education",fontsize = 14)
plt.xlabel("Counties",fontsize =14)
plt.xticks(rotation=90);

# %%
## Poverty

Poverty = np.array(countydf['Poverty'])

plt.figure(figsize=(20,5))
plt.plot( county, Poverty , marker='o', color='mediumvioletred')
plt.title("Counties by Poverty", fontsize = 17)
plt.ylabel("Poverty",fontsize = 14)
plt.xlabel("Counties",fontsize =14)
plt.xticks(rotation=90);

# %%
## Housing Burden

HousingBurden = np.array(countydf['Housing Burden'])

plt.figure(figsize=(20,5))
plt.plot( county, HousingBurden , marker='o', color='mediumvioletred')
plt.title("Counties by Housing Burden", fontsize = 17)
plt.ylabel("Housing Burden",fontsize = 14)
plt.xlabel("Counties",fontsize =14)
plt.xticks(rotation=90);
